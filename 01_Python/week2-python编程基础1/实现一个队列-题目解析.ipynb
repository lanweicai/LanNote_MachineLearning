# %% [markdown]
# # 实现一个队列

# %% [markdown]
# ## 学前准备
# - 对于0基础的同学，建议预先完成https://learn.kaikeba.com/catalog/210665《全院python基础入门》 课程中，第一章 第二章 第三章 第五章的学习，其中第一章内容在《0基础python》中已经直播讲过。
#
# - 周三《0基础python》选修课会包含该部分所有知识点，课程结束后，会以练习题作为复习题讲解。

# %% [markdown]
# ## 题目描述：
# ### 1. 使用数组实现一个队列，要求具有以下方法
# - 入队列
# - 出队列
# - 产看队列`首`、`尾`元素
# - 查看队列大小
# ### 2. 队列操作
# - 新建一个队列（命名为q1）
# - 将数组ls_1 按索引从小到大进行入队操作
# - 输出队列中元素个数
# - 获取队首元素，保存在变量q1_gettop中，观察栈中元素个数
# - 弹出栈顶元素,保存在变量s1_poptop中，观察栈中元素个数

# %% [markdown]
# ## 提示

# %% [markdown]
# ### 1.队列（queue）

# %% [markdown]
# ![duilie_inf.jpg](attachment:duilie_inf.jpg)

# %% [markdown]
# ### 简介
# - 一种常用数据结构
# - 先进先出（FIFO-first in first out）:最先插入的元素最先出来

# %% [markdown]
# ### 注
# - 使用数组实现队列，当进行出队操作后，数组前半部分kong jian

# %%
class MyQueue:
    def __init__(self):
        self.arr = []
        self.front = 0   #队首索引(指针)
        self.rear = 0    #队尾索引（指针）
    
    #判断队列是否为空
    def is_empty(self):
        return self.front == self.rear
    
    #返回队列大小
    def size(self):
        return self.rear - self.front
    
    #返回队列首元素
    def get_front(self):
        #先判断队列是否为空，为空返回None，否则返回队首元素
        if self.is_empty():
            return None
        else:
            return self.arr[self.front]
        
    #返回队尾元素
    def get_rear(self):
        #先判断队列是否为空，为空返回None，否则返回队尾元素
        if self.is_empty():
            return None
        else:
            return self.arr[self.rear-1]

    #出队（更换队首）
    def de_queue(self):
        #先判断队列是否为空
        if self.rear > self.front:
            self.front += 1
        else:
            print('队列已空')
    
    #入队
    def en_queue(self, item):
        #队尾插入新元素后，注意更新队尾索引（指针）
        self.arr.append(item)
        self.rear += 1

# %% [markdown]
# ## 队列操作

# %% [markdown]
# ### 新建一个队列（命名为q1）
# - 将数组ls_1 按索引从小到大进行入队操作
# - 输出队列中元素个数
# - 获取队首元素，保存在变量q1_getfront中，打印队列中元素个数
# - 获取队尾元素，保存在变量q1_getrear中，打印队列元素个数
# - 执行出队操作，打印出队前后队首索引、队尾索引、队列元素个数

# %%
q1 = MyQueue()
q1

# %% [markdown]
# ### 将数组ls_1 按索引从小到大进行入队操作

# %%
ls_1 = list(range(1,10,2))
ls_1
# Out:
# [1, 3, 5, 7, 9]

# %%
for i in ls_1:
    q1.en_queue(i)

# %% [markdown]
# ### 输出队列中元素个数

# %%
q1.size()
# Out:
# 5

# %% [markdown]
# ### 获取队首元素，保存在变量q1_getfront中，打印队列中元素个数

# %%
q1_getfront = q1.get_front()
print('队首元素为：{}'.format(q1_getfront))
print('队列长度为：{}'.format(q1.size()))
# Out:
# 队首元素为：1
# 队列长度为：5

# %% [markdown]
# ### 获取队尾元素，保存在变量q1_getrear中，打印队列元素个数

# %%
q1_getrear = q1.get_rear()
print('队尾元素为：{}'.format(q1_getrear))
print('队列长度为：{}'.format(q1.size()))
# Out:
# 队尾元素为：9
# 队列长度为：5

# %% [markdown]
# ### 执行出队操作，打印出队前后队首索引、队尾索引、队列元素个数

# %%
print('队首索引为:{}\n队尾索引为：{}'.format(q1.front, q1.rear))
q1.de_queue()
print('****************')
print('队首索引为:{}\n队尾索引为：{}'.format(q1.front, q1.rear))
# Out:
# 队首索引为:0
# 队尾索引为：5
# ****************
# 队首索引为:1
# 队尾索引为：5
